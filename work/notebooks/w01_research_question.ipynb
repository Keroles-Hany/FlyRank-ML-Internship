# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Keroles-Hany/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# #I have chosen the Refresh / Content Opportunity Scoring lane. I chose this because it allows me to build a practical, decision-support system that directly helps SEO teams prioritize their workload. Instead of generic analysis, this lane focuses on providing actionable 'review queues,' which aligns perfectly with my work on detecting content stability and performance declines using observable data signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# #My work focuses on improving the decision-making process for content refreshes by prioritizing which pages need an SEO audit first.
#
# #The primary user of this output is the SEO team, who will use the ranked queue to focus their efforts on pages with the highest risk of traffic loss rather than auditing the entire inventory manually.
#
# #The cost of a wrong call is two-fold: a false positive wastes the team's limited time on a stable page, while a false negative results in missed opportunities to recover traffic that could have been saved with an earlier update.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# #I examined the starter dataset to verify that it captures meaningful variation in search performance. By looking at the traffic trends and volume, I found a substantial number of items that are currently trending downwards, which validates that this lane is not just a theoretical exercise but a way to address a real inventory management problem

# %%
# !git clone https://github.com/Keroles-Hany/FlyRank-ML-Internship.git
# Out:
# fatal: destination path 'FlyRank-ML-Internship' already exists and is not an empty directory.

# %%
# Load dataset from the cloned repo
file_path = 'FlyRank-ML-Internship/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(file_path)

# 1. Total volume
print(f"Total content items analyzed: {len(df):,}")

# 2. Potential refresh candidates
declining_items = df[df['trend_direction'].str.lower() == 'down']
print(f"Items with a downward trend: {len(declining_items):,}")

# 3. Volume context (for noise filtering)
print(f"Average impressions per item: {df['impressions_90d'].mean():.0f}")
# Out:
# Total content items analyzed: 30,000
# Items with a downward trend: 16,262
# Average impressions per item: 5200

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# #My analysis is observational. Looking at the 30,000 items in the dataset, I can highlight patterns, like the 16,000+ pages trending downward, to help teams decide what to review first. I cannot prove these patterns cause traffic drops, nor can I predict future rankings. This is a prioritization tool for human experts, not a 'Google-predicting' model.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅ ] Every section above is filled — markdown thinking AND the code that backs it
# - [✅ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅ ] No client names, URLs, or private queries anywhere
# - [✅ ] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
